# %%
contexts = [
    "The system of judicial administration introduced by Warren Hastings was equally cautious and experimental",
    "Bengal zemindars ceased to act as magistrates or judges. The British collector became magistrate and civil judge",
    "As magistrate he made over all prisoners for trial to a Mohammedan court, which was created in each district, but over which he maintained some degree of control ",
    "A cazi sat as judge and tried the prisoners, whilst muftis and mulvis expounded or interpreted Mohammedan law",
    "The British collector was present to see that trials were properly conducted, and perhaps to intercede when the punishment awarded was barbarous or cruel",
    "This was little more than a reform of the existing systemâ€”such a reform as might have been carried out by an Akbar or Aurangzeb",
    "For centuries Mohammedan law had been the common law of Northern India, and Hindu criminal law, with its hideous severities as regards caste"
]

# %%
questions_answers = [
{
    "context_index": 0,
    "question": "What was the nature of the system of judicial administration introduced by Warren Hastings?",
    "answer": "equally cautious and experimental"
},
{
    "context_index": 0,
    "question": "Who was responsible for introducing the cautious and experimental system of judicial administration?",
    "answer": "Warren Hastings"
},
{
    "context_index": 0,
    "question": "In terms of caution and experimentation, how did Warren Hastings approach the judicial administration system?",
    "answer": "equally"
},
{
    "context_index": 0,
    "question": "What adjective best describes the judicial administration system implemented by Warren Hastings?",
    "answer": "cautious and experimental"
},
{
    "context_index": 0,
    "question": "Which historical figure implemented a judicial administration system that was both cautious and experimental?",
    "answer": "Warren Hastings"
}
,
{
"context_index": 1,
"question": "What role did Bengal zemindars previously play in the judicial system?",
"answer": "Bengal zemindars ceased to act as magistrates or judges."
},
{
"context_index": 1,
"question": "Who assumed the role of magistrate and civil judge in place of Bengal zemindars?",
"answer": "The British collector became magistrate and civil judge."
},
{
"context_index": 1,
"question": "What impact did the change in the judicial system have on Bengal zemindars?",
"answer": "Bengal zemindars ceased to act as magistrates or judges."
},
{
"context_index": 1,
"question": "In the new judicial system, who took on the responsibilities of a magistrate?",
"answer": "The British collector."
},
{
"context_index": 1,
"question": "Which two roles did the British collector assume in the changed judicial administration?",
"answer": "Magistrate and civil judge."
},
    {
        "context_index": 2,
        "question": "To which court did the magistrate turn over all prisoners for trial?",
        "answer": "Mohammedan court"
    },
    {
        "context_index": 2,
        "question": "What kind of control did the magistrate maintain over the Mohammedan court?",
        "answer": "some degree of control"
    },
    {
        "context_index": 2,
        "question": "In each district, what type of court was created for the trial of prisoners?",
        "answer": "Mohammedan court"
    },
    {
        "context_index": 2,
        "question": "Who had the authority to make over prisoners for trial to the Mohammedan court?",
        "answer": "magistrate"
    },
    {
        "context_index": 2,
        "question": "How did the magistrate manage the newly created Mohammedan courts?",
        "answer": "maintained some degree of control"
    },
 {
    "context_index": 3,
    "question": "Who presided as the judge during the trials of prisoners?",
    "answer": "A cazi"
},
{
    "context_index": 3,
    "question": "What role did muftis and mulvis play in the judicial proceedings?",
    "answer": "They expounded or interpreted Mohammedan law"
},
{
    "context_index": 3,
    "question": "What was the responsibility of the cazi in the judicial process?",
    "answer": "To sit as judge and try the prisoners"
},
{
    "context_index": 3,
    "question": "In what capacity did muftis and mulvis contribute to the legal proceedings?",
    "answer": "They expounded or interpreted Mohammedan law"
},
{
    "context_index": 3,
    "question": "What type of law did the muftis and mulvis interpret during the trials?",
    "answer": "Mohammedan law"
},
     {
        "context_index": 4,
        "question": "Who was present to ensure the proper conduct of trials?",
        "answer": "The British collector"
    },
    {
        "context_index": 4,
        "question": "What was the role of the British collector during trials?",
        "answer": "To see that trials were properly conducted and perhaps to intercede in cases of barbarous or cruel punishment"
    },
    {
        "context_index": 4,
        "question": "Why was the British collector present during trials?",
        "answer": "To ensure proper conduct and possibly intercede in cases of barbarous or cruel punishment"
    },
    {
        "context_index": 4,
        "question": "What was the purpose of the British collector's presence during trials?",
        "answer": "To witness proper conduct and potentially intervene in cases of barbarous or cruel punishment"
    },
    {
        "context_index": 4,
        "question": "In what situations might the British collector intercede during trials?",
        "answer": "When the punishment awarded was barbarous or cruel"
    },
       {
    "context_index": 5,
    "question": "Who is mentioned as potential reformers comparable to the one who carried out the reform?",
    "answer": "Akbar or Aurangzeb"
},
{
    "context_index": 5,
    "question": "What is the nature of the reform mentioned in the context?",
    "answer": "little more than a reform of the existing system"
},
{
    "context_index": 5,
    "question": "Who are the historical figures referenced as potential reformers in the context?",
    "answer": "Akbar and Aurangzeb"
},
{
    "context_index": 5,
    "question": "In comparison to what historical figures, is the reform described in the context?",
    "answer": "Akbar or Aurangzeb"
},
{
    "context_index": 5,
    "question": "How significant was the reform mentioned in the context?",
    "answer": "little more than a reform of the existing system"
},
                          {
        "context_index": 6,
        "question": "What was the common law of Northern India for centuries?",
        "answer": "Mohammedan law"
    },
    {
        "context_index": 6,
        "question": "Which region was predominantly governed by Mohammedan law for centuries?",
        "answer": "Northern India"
    },
    {
        "context_index": 6,
        "question": "What characterized Hindu criminal law in Northern India?",
        "answer": "hideous severities as regards caste"
    },
    {
        "context_index": 6,
        "question": "How long had Mohammedan law been the common law in Northern India?",
        "answer": "centuries"
    },
    {
        "context_index": 6,
        "question": "What does the context mention about Hindu criminal law?",
        "answer": "hideous severities as regards caste"
    }

]

# %%
train_data = []
contexts_data = []

for i, context in enumerate(contexts):
    qas = []
    for qa in questions_answers:
        if qa["context_index"] == i:
            answer_start = context.find(qa["answer"])
            if answer_start != -1:
                qas.append({
                    "id": str(len(qas) + 1).zfill(5),
                    "is_impossible": False,
                    "question": qa["question"],
                    "answers": [
                        {
                            "text": qa["answer"],
                            "answer_start": answer_start,
                        }
                    ],
                })
    contexts_data.append({
        "context": context,
        "qas": qas,
    })

train_data.extend(contexts_data)

# Print the train_data to verify the format
import json
# print(json.dumps(train_data, indent=4))

with open('train.json', 'w', encoding='utf-8') as f:
    json.dump(train_data, f, ensure_ascii=False, indent=4)

# %%
contexts = [
    "Civil justice was administered more directly by the British collectors.",
    "In civil disputes, especially as regards inheritance and marriage, the parties concerned were necessarily guided by their own laws.",
    "Accordingly, the collector sat as judge but was assisted by Mohammedan lawyers in deciding cases between Mohammedans, and by learned Brahmans, or pundits, in deciding cases between Hindus.",
    "Under most circumstances, the cazi or pundit must often have been the real judge, whilst the British collector was only the representative of the supreme authority."
]

questions_answers = [
 {
    "context_index": 0,
    "question": "Who was responsible for administering civil justice?",
    "answer": "British collectors"
},
{
    "context_index": 0,
    "question": "How was civil justice administered under British rule?",
    "answer": "more directly by the British collectors"
},
{
    "context_index": 0,
    "question": "What was the role of the British collectors in the administration of civil justice?",
    "answer": "They were directly involved in administering civil justice"
},
{
    "context_index": 0,
    "question": "In the context, who played a significant role in the direct administration of civil justice?",
    "answer": "British collectors"
},
{
    "context_index": 0,
    "question": "How did the British handle the administration of civil justice?",
    "answer": "They administered it more directly"
},
 {
    "context_index": 1,
    "question": "What were the guiding factors for parties involved in civil disputes related to inheritance and marriage?",
    "answer": "their own laws"
},
{
    "context_index": 1,
    "question": "In which types of disputes were parties particularly guided by their own laws?",
    "answer": "civil disputes, especially in inheritance and marriage"
},
{
    "context_index": 1,
    "question": "What aspects of civil disputes were the parties concerned guided by their own laws?",
    "answer": "inheritance and marriage"
},
{
    "context_index": 1,
    "question": "In the context of civil disputes, what laws did the parties involved follow?",
    "answer": "their own laws"
},
{
    "context_index": 1,
    "question": "When it came to inheritance and marriage in civil disputes, what played a crucial role in guiding the parties?",
    "answer": "their own laws"
},
 {
    "context_index": 2,
    "question": "Who sat as judge in the judicial administration system described?",
    "answer": "the collector"
},
{
    "context_index": 2,
    "question": "Who assisted the collector in deciding cases between Mohammedans?",
    "answer": "Mohammedan lawyers"
},
{
    "context_index": 2,
    "question": "Who assisted the collector in deciding cases between Hindus?",
    "answer": "learned Brahmans, or pundits"
},
{
    "context_index": 2,
    "question": "In what capacity did the collector sit as judge?",
    "answer": "judicial"
},
{
    "context_index": 2,
    "question": "What role did Mohammedan lawyers play in the judicial administration system?",
    "answer": "assisting in deciding cases between Mohammedans"
},
 {
    "context_index": 3,
    "question": "Who was typically the real judge under most circumstances?",
    "answer": "the cazi or pundit"
},
{
    "context_index": 3,
    "question": "What role did the British collector play in the judicial administration?",
    "answer": "representative of the supreme authority"
},
{
    "context_index": 3,
    "question": "In the described circumstances, who held the position of the supreme authority?",
    "answer": "the British collector"
},
{
    "context_index": 3,
    "question": "What was the primary role of the cazi or pundit in the judicial system?",
    "answer": "the real judge"
},
{
    "context_index": 3,
    "question": "How would you characterize the British collector's authority in the judicial process?",
    "answer": "only the representative of the supreme authority"
}


]

# %%
train_data = []
contexts_data = []

for i, context in enumerate(contexts):
    qas = []
    for qa in questions_answers:
        if qa["context_index"] == i:
            answer_start = context.find(qa["answer"])
            if answer_start != -1:
                qas.append({
                    "id": str(len(qas) + 1).zfill(5),
                    "is_impossible": False,
                    "question": qa["question"],
                    "answers": [
                        {
                            "text": qa["answer"],
                            "answer_start": answer_start,
                        }
                    ],
                })
    contexts_data.append({
        "context": context,
        "qas": qas,
    })

train_data.extend(contexts_data)

# Print the train_data to verify the format
import json
# print(json.dumps(train_data, indent=4))

with open('test.json', 'w', encoding='utf-8') as f:
    json.dump(train_data, f, ensure_ascii=False, indent=4)

# %%
pip install simpletransformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.8/250.8 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 23.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 52.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 63.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 33.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 17.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.2/249.2 kB 22.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 60.7 MB/s eta 0:00:00
# ...

# %%
# Import required libraries to fine tune transformer models lik BERT
import json
import logging
from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

# Read dataset to fine tune BERT model

# Training data
with open(r"/content/train.json", "r") as read_file:
    train = json.load(read_file)

# Validation dataset
with open(r"/content/test.json", "r") as read_file:
    test = json.load(read_file)

# %%
model_type = "bert"
model_name = "bert-large-uncased-whole-word-masking-finetuned-squad"

# %%
# Create folder to save fine tuned bert model inside working directory

import os
output_dir = 'bert_outputs'
os.mkdir(output_dir)

# %%
# Define transformer model arguments before training the BERT model

train_args = {
    "reprocess_input_data": True,
    "overwrite_output_dir": True,
    "use_cached_eval_features": True,
    "output_dir": f"outputs/{model_type}",
    "best_model_dir": f"{output_dir}/{model_type}/best_model",
    "evaluate_during_training": True,
    "max_seq_length": 128,
    "num_train_epochs": 100,
    "evaluate_during_training_steps": 1000,
    "save_model_every_epoch": False,
    "save_eval_checkpoints": False,
    "n_best_size":8,
    "train_batch_size": 8,
    "eval_batch_size": 8
}

model = QuestionAnsweringModel(model_type,model_name, args=train_args, use_cuda=False)
# Out:
# config.json:   0%|          | 0.00/443 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-large-uncased-whole-word-masking-finetuned-squad were not used when initializing BertForQuestionAnswering: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# ...

# %%
# Train the model
model.train_model(train, eval_data=test)
# Out:
# ...
# convert squad examples to features: 100%|██████████| 15/15 [00:00<00:00, 519.19it/s]
#
# ...
# Running Evaluation:   0%|          | 0/2 [00:00<?, ?it/s]
# (300,
#  {'global_step': [3,
#    6,
#    9,
#    12,
#    15,
#    18,
#    21,
#    24,
#    27,
#    30,
#    33,
#    36,
#    39,
#    42,
#    45,
#    48,
#    51,
#    54,
#    57,
#    60,
#    63,
#    66,
#    69,
#    72,
#    75,
#    78,
#    81,
#    84,
#    87,
#    90,
#    93,
#    96,
#    99,
#    102,
#    105,
#    108,
#    111,
#    114,
#    117,
#    120,
#    123,
#    126,
#    129,
#    132,
#    135,
#    138,
#    141,
#    144,
#    147,
#    150,
#    153,
#    156,
#    159,
#    162,
#    165,
#    168,
#    171,
#    174,
#    177,
#    180,
#    183,
#    186,
#    189,
#    192,
#    195,
#    198,
#    201,
#    204,
#    207,
#    210,
#    213,
#    216,
#    219,
#    222,
#    225,
#    228,
#    231,
#    234,
#    237,
#    240,
#    243,
#    246,
#    249,
#    252,
#    255,
#    258,
# ...

# %%
# Evaluate the model
result, texts = model.eval_model(test)
# Out:
# Running Evaluation:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Load model from training checkpoint
from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

model = QuestionAnsweringModel("bert", "/content/bert_outputs/bert/best_model", use_cuda=False)


# Make predictions with the model
to_predict = [
    {
        "context": "The system of judicial administration introduced by Warren Hastings was equally cautious and experimental. Bengal zemindars ceased to act as magistrates or judges. The British collector became magistrate and civil judge. As magistrate he made over all prisoners for trial to a Mohammedan court, which was created in each district, but over which he maintained some degree of control. A cazi sat as judge and tried the prisoners, whilst muftis and mulvis expounded or interpreted Mohammedan law; but the British collector was present to see that trials were properly conducted, and perhaps to intercede when the punishment awarded was barbarous or cruel. This was little more than a reform of the existing systemâ€”such a reform as might have been carried out by an Akbar or Aurangzeb. For centuries Mohammedan law had been the common law of Northern India, and Hindu criminal law, with its hideous severities as regards caste, had been ignored by Mogul rulers, although, no doubt, caste laws were often enforced by the Hindus themselves.",
        "qas": [
            {
                "question": "Who was responsible for introducing the cautious and experimental system of judicial administration?",
                "id": "0",
            }
        ],
    }
]

answers, probabilities = model.predict(to_predict, n_best_size=1)
print(answers)
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'id': '0', 'answer': ['Warren Hastings']}]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
import os

source_folder = "/content/bert_outputs"
destination_folder = "/content/drive/MyDrive/bert_large_uncased"

# Check if the source folder exists
if os.path.exists(source_folder):
    # Ensure the destination folder exists
    if not os.path.exists(destination_folder):
        os.makedirs(destination_folder)

    # Copy the entire directory
    shutil.copytree(source_folder, os.path.join(destination_folder, os.path.basename(source_folder)))
    print(f"Directory copied successfully to {destination_folder}")
else:
    print("Source folder not found.")
# Out:
# Directory copied successfully to /content/drive/MyDrive/bert_large_uncased

# %%
# Load model from training checkpoint
from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

model = QuestionAnsweringModel("bert", "/content/drive/MyDrive/bert_large_uncased/bert_outputs/bert/best_model", use_cuda=False)


# Make predictions with the model
to_predict = [
    {
        "context": "The system of judicial administration introduced by Warren Hastings was equally cautious and experimental. Bengal zemindars ceased to act as magistrates or judges. The British collector became magistrate and civil judge. As magistrate he made over all prisoners for trial to a Mohammedan court, which was created in each district, but over which he maintained some degree of control. A cazi sat as judge and tried the prisoners, whilst muftis and mulvis expounded or interpreted Mohammedan law; but the British collector was present to see that trials were properly conducted, and perhaps to intercede when the punishment awarded was barbarous or cruel. This was little more than a reform of the existing systemâ€”such a reform as might have been carried out by an Akbar or Aurangzeb. For centuries Mohammedan law had been the common law of Northern India, and Hindu criminal law, with its hideous severities as regards caste, had been ignored by Mogul rulers, although, no doubt, caste laws were often enforced by the Hindus themselves.",
        "qas": [
            {
                "question": "What were the roles of muftis and mulvis in the judicial process?",
                "id": "0",
            }
        ],
    }
]

answers, probabilities = model.predict(to_predict, n_best_size=1)
print(answers)
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'id': '0', 'answer': ['expounded or interpreted Mohammedan law;']}]

# %%
# Load model from training checkpoint
from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

model = QuestionAnsweringModel("bert", "/content/drive/MyDrive/bert_large_uncased/bert_outputs/bert/best_model", use_cuda=False)


# Make predictions with the model
to_predict = [
    {
        "context": "Meanwhile the Governor and Council still formed the chief court at Calcutta, and confirmed all capital sentences, or heard appeals in important civil cases, as in the old times when British authority was bounded by the Mahratta ditch. From time to time they passed regulations for the guidance of collectors, and eventually Warren Hastings drew up a clear and concise criminal code with his own hands. This chief court was known as the Sudder. It had a civil and a criminal side, and lasted as an institution down to the latest days of the East India Company.",
        "qas": [
            {
                "question": "Which court confirmed or heard appeals in civil cases?",
                "id": "0",
            }
        ],
    }
]

answers, probabilities = model.predict(to_predict, n_best_size=1)
print(answers)
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'id': '0', 'answer': ['chief court at Calcutta,']}]

# %%
# Load model from training checkpoint
from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

model = QuestionAnsweringModel("bert", "/content/drive/MyDrive/bert_large_uncased/bert_outputs/bert/best_model", use_cuda=False)


# Make predictions with the model
to_predict = [
    {
        "context": "Meanwhile the Governor and Council still formed the chief court at Calcutta, and confirmed all capital sentences, or heard appeals in important civil cases, as in the old times when British authority was bounded by the Mahratta ditch. From time to time they passed regulations for the guidance of collectors, and eventually Warren Hastings drew up a clear and concise criminal code with his own hands. This chief court was known as the Sudder. It had a civil and a criminal side, and lasted as an institution down to the latest days of the East India Company.",
        "qas": [
            {
                "question": "Who were the members of the chief court that formed the highest authority?",
                "id": "0",
            }
        ],
    }
]

answers, probabilities = model.predict(to_predict, n_best_size=1)
print(answers)
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'id': '0', 'answer': ['Governor and Council']}]

# %%
# Load model from training checkpoint
from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

model = QuestionAnsweringModel("bert", "/content/drive/MyDrive/bert_large_uncased/bert_outputs/bert/best_model", use_cuda=False)


# Make predictions with the model
to_predict = [
    {
        "context": "Meanwhile the Governor and Council still formed the chief court at Calcutta, and confirmed all capital sentences, or heard appeals in important civil cases, as in the old times when British authority was bounded by the Mahratta ditch. From time to time they passed regulations for the guidance of collectors, and eventually Warren Hastings drew up a clear and concise criminal code with his own hands. This chief court was known as the Sudder. It had a civil and a criminal side, and lasted as an institution down to the latest days of the East India Company.",
        "qas": [
            {
                "question": "Can you provide information on the individuals who comprised the highest authority within the chief court?",
                "id": "0",
            }
        ],
    }
]

answers, probabilities = model.predict(to_predict, n_best_size=1)
print(answers)
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'id': '0', 'answer': ['Meanwhile the Governor and Council']}]

# %%
# Load model from training checkpoint
from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

model = QuestionAnsweringModel("bert", "/content/drive/MyDrive/bert_large_uncased/bert_outputs/bert/best_model", use_cuda=False)


# Make predictions with the model
to_predict = [
    {
        "context": "Meanwhile the Governor and Council still formed the chief court at Calcutta, and confirmed all capital sentences, or heard appeals in important civil cases, as in the old times when British authority was bounded by the Mahratta ditch. From time to time they passed regulations for the guidance of collectors, and eventually Warren Hastings drew up a clear and concise criminal code with his own hands. This chief court was known as the Sudder. It had a civil and a criminal side, and lasted as an institution down to the latest days of the East India Company.",
        "qas": [
            {
                "question": "Who were the members constituting the highest authority in the chief court?",
                "id": "0",
            }
        ],
    }
]

answers, probabilities = model.predict(to_predict, n_best_size=1)
print(answers)
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'id': '0', 'answer': ['Governor and Council']}]

# %%
# Load model from training checkpoint
from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

model = QuestionAnsweringModel("bert", "/content/drive/MyDrive/bert_large_uncased/bert_outputs/bert/best_model", use_cuda=False)


# Make predictions with the model
to_predict = [
    {
        "context": "Meanwhile the Governor and Council still formed the chief court at Calcutta, and confirmed all capital sentences, or heard appeals in important civil cases, as in the old times when British authority was bounded by the Mahratta ditch. From time to time they passed regulations for the guidance of collectors, and eventually Warren Hastings drew up a clear and concise criminal code with his own hands. This chief court was known as the Sudder. It had a civil and a criminal side, and lasted as an institution down to the latest days of the East India Company.",
        "qas": [
            {
                "question": "Please identify the members who were part of the highest authority in the chief court.",
                "id": "0",
            }
        ],
    }
]

answers, probabilities = model.predict(to_predict, n_best_size=1)
print(answers)
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'id': '0', 'answer': ['Meanwhile the Governor and Council']}]

# %%
# Load model from training checkpoint
from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

model = QuestionAnsweringModel("bert", "/content/drive/MyDrive/bert_large_uncased/bert_outputs/bert/best_model", use_cuda=False)


# Make predictions with the model
to_predict = [
    {
        "context": "Meanwhile the Governor and Council still formed the chief court at Calcutta, and confirmed all capital sentences, or heard appeals in important civil cases, as in the old times when British authority was bounded by the Mahratta ditch. From time to time they passed regulations for the guidance of collectors, and eventually Warren Hastings drew up a clear and concise criminal code with his own hands. This chief court was known as the Sudder. It had a civil and a criminal side, and lasted as an institution down to the latest days of the East India Company.",
        "qas": [
            {
                "question": "Could you list the individuals who made up the chief court's highest authority?",
                "id": "0",
            }
        ],
    }
]

answers, probabilities = model.predict(to_predict, n_best_size=1)
print(answers)
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'id': '0', 'answer': ['Meanwhile the Governor and Council']}]

# %%
# Load model from training checkpoint
from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

model = QuestionAnsweringModel("bert", "/content/drive/MyDrive/CSE498R/Model/bert_large_uncased/bert_outputs/bert/best_model", use_cuda=False)


# Make predictions with the model
to_predict = [
    {
        "context": "Meanwhile the Governor and Council still formed the chief court at Calcutta, and confirmed all capital sentences, or heard appeals in important civil cases, as in the old times when British authority was bounded by the Mahratta ditch. From time to time they passed regulations for the guidance of collectors, and eventually Warren Hastings drew up a clear and concise criminal code with his own hands. This chief court was known as the Sudder. It had a civil and a criminal side, and lasted as an institution down to the latest days of the East India Company.",
        "qas": [
            {
                "question": "What were the responsibilities of the Sudder court?",
                "id": "0",
            }
        ],
    }
]

answers, probabilities = model.predict(to_predict, n_best_size=1)
print(answers)
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'id': '0', 'answer': ['confirmed all capital sentences, or heard appeals in important civil cases']}]

# %%
# Load model from training checkpoint
from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

model = QuestionAnsweringModel("bert", "/content/drive/MyDrive/CSE498R/Model/bert_large_uncased/bert_outputs/bert/best_model", use_cuda=False)


# Make predictions with the model
to_predict = [
    {
        "context": "Under such circumstances British ideas of justice gradually superseded Mohammedan usages. Indeed it was impossible to maintain the criminal law of the Mohammedans in courts controlled more or less by British judges. Under Mohammedan law theft was punished by mutilation, adultery was punished by death, or not punished at all unless four eye-witnesses could be produced; whilst the most atrocious murderer might escape from justice by the payment of a blood fine to the kinsmen of his victim. Cazis and muftis might be nominally independent, but practically they yielded to British influences; and British judges administered justice in a patriarchal fashion, which might be condemned by trained lawyers, but was far better suited to the condition of the masses than British courts of law in the last century.",
        "qas": [
            {
                "question": "How was adultery punished under Mohammedan law?",
                "id": "0",
            }
        ],
    }
]

answers, probabilities = model.predict(to_predict, n_best_size=1)
print(answers)
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# [{'id': '0', 'answer': ['death']}]

# %%
from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

# Load the pre-trained model
model = QuestionAnsweringModel("bert", "/content/drive/MyDrive/CSE498R/Model/bert_large_uncased/bert_outputs/bert/best_model", use_cuda=False)

while True:
    # Take user input
    user_input = input("\nAsk a question (or type 'exit' to end): ")

    # Check if the user wants to exit the loop
    if user_input.lower() == 'exit':
        break

    # Make predictions with the model
    to_predict = [
        {
            "context": "Courts of circuit and appeal were also appointed to travel through different areas, and sit as British judges of assize in both criminal and civil courts. Here was that same mixture of British and Asiatic judges as in the collectors' courts. But many changes were made from time to time in the judicial system, and the whole question will be better considered hereafter when dealing with the reforms of Lord Cornwallis, who eventually succeeded Warren Hastings as Governor-General.",
            "qas": [
                {
                    "question": user_input,
                    "id": "0",
                }
            ],
        }
    ]

    # Get the model's answer
    answers, probabilities = model.predict(to_predict, n_best_size=1)
    print("Answer:", answers[0]['answer'])
    print()
# Out:
# Ask a question (or type 'exit' to end): What types of courts were appointed to travel through different areas?
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# Answer: ['Courts of circuit and appeal']
#
#
# Ask a question (or type 'exit' to end):  In what capacity did the British judges appointed to travel serve in both criminal and civil courts?
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# Answer: ['British judges of assize']
#
#
# Ask a question (or type 'exit' to end): How would you describe the composition of the courts in terms of judges in different areas?
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# Answer: ['Here was that same mixture of British and Asiatic judges']
#
#
# Ask a question (or type 'exit' to end): Were there any changes made in the judicial system over time?
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# Answer: ['many changes']
#
#
# ...

# %%
from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

# Load the pre-trained model
model = QuestionAnsweringModel("bert", "/content/bert_outputs/bert/best_model", use_cuda=False)

while True:
    # Take user input
    user_input = input("\nAsk a question (or type 'exit' to end): ")

    # Check if the user wants to exit the loop
    if user_input.lower() == 'exit':
        break

    # Make predictions with the model
    to_predict = [
        {
            "context": "Civil justice was administered more directly by the British collectors. In civil disputes, especially as regards inheritance and marriage, the parties concerned were necessarily guided by their own laws. Accordingly the collector sat as judge, but was assisted by Mohammedan lawyers in deciding cases between Mohammedans, and by learned Brahmans, or pundits, in deciding cases between Hindus. Under most circumstances the cazi or pundit must often have been the real judge, whilst the British collector was only the representative of the supreme authority.",
            "qas": [
                {
                    "question": user_input,
                    "id": "0",
                }
            ],
        }
    ]

    # Get the model's answer
    answers, probabilities = model.predict(to_predict, n_best_size=1)
    print("Answer:", answers[0]['answer'])
    print()
# Out:
# Ask a question (or type 'exit' to end): Who administered civil justice more directly in the described context?
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# Answer: ['British collectors.']
#
#
# Ask a question (or type 'exit' to end): What laws did parties involved in civil disputes follow, especially concerning inheritance and marriage?
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# Answer: ['their own laws']
#
#
# Ask a question (or type 'exit' to end): In civil disputes, who sat as a judge in the described scenario?
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# Answer: ['Accordingly the collector']
#
#
# Ask a question (or type 'exit' to end): In civil cases involving Mohammedans, who assisted the British collector in deciding the disputes?
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# Answer: ['learned Brahmans, or pundits,']
#
#
# ...

# %%
from simpletransformers.question_answering import QuestionAnsweringModel, QuestionAnsweringArgs

# Load the pre-trained model
model = QuestionAnsweringModel("bert", "/content/drive/MyDrive/CSE498R/Model/bert_large_uncased/bert_outputs/bert/best_model", use_cuda=False)

while True:
    # Take user input
    user_input = input("\nAsk a question (or type 'exit' to end): ")

    # Check if the user wants to exit the loop
    if user_input.lower() == 'exit':
        break

    # Make predictions with the model
    to_predict = [
        {
            "context": "The system of judicial administration introduced by Warren Hastings was equally cautious and experimental. Bengal zemindars ceased to act as magistrates or judges. The British collector became magistrate and civil judge. As magistrate he made over all prisoners for trial to a Mohammedan court, which was created in each district, but over which he maintained some degree of control. A cazi sat as judge and tried the prisoners, whilst muftis and mulvis expounded or interpreted Mohammedan law; but the British collector was present to see that trials were properly conducted, and perhaps to intercede when the punishment awarded was barbarous or cruel. This was little more than a reform of the existing systemâ€”such a reform as might have been carried out by an Akbar or Aurangzeb. For centuries Mohammedan law had been the common law of Northern India, and Hindu criminal law, with its hideous severities as regards caste, had been ignored by Mogul rulers, although, no doubt, caste laws were often enforced by the Hindus themselves.",
            "qas": [
                {
                    "question": user_input,
                    "id": "0",
                }
            ],
        }
    ]

    # Get the model's answer
    answers, probabilities = model.predict(to_predict, n_best_size=1)
    print("Answer:", answers[0]['answer'])
    print()
# Out:
# Ask a question (or type 'exit' to end): What changes did Warren Hastings introduce in the judicial administration system?
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# Answer: ['equally cautious and experimental']
#
#
# Ask a question (or type 'exit' to end): The system of judicial administration introduced by whom?
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# Answer: ['Warren Hastings']
#
#
# Ask a question (or type 'exit' to end): What was introduced by Warren Hastings?
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# Answer: ['empty']
#
#
# Ask a question (or type 'exit' to end): What is equally cautious and experimental?
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# Answer: ['The system of judicial administration']
#
#
# Ask a question (or type 'exit' to end): what system was introduced by warren hastings?
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]
# Answer: ['equally cautious and experimental']
#
#
# ...
